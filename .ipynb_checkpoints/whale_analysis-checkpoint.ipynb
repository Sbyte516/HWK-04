# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returnscsv
whale_returns_csv = Path("C:/Users/sebas/Desktop/Jupyter_Lab_Notebook/Resources/whale_returns.csv")
whale_returns_csv = pd.read_csv(whale_returns_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)
whale_returns_csv.sort_index(inplace = True)
whale_returns_csv
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_returns_csv.isnull().values.sum()
# Out:
# 4

# %%
whale_returns_csv.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale = whale_returns_csv.drop(whale_returns_csv.index[0])

# %%
# Drop nulls
whale.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("C:/Users/sebas/Desktop/Jupyter_Lab_Notebook/Resources/algo_returns.csv")
algo = pd.read_csv(algo_returns_csv, index_col='Date' , infer_datetime_format=True, parse_dates=True)
algo.sort_index(inplace=True)
algo.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
algo.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo = algo.dropna(how='any')
algo
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
# Drop nulls
algo.isna().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("C:/Users/sebas/Desktop/Jupyter_Lab_Notebook/Resources/sp500_history.csv")
sp500 = pd.read_csv(sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500.sort_index(inplace =True)
sp500
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93
# ...              ...
# 2019-04-16  $2907.06
# 2019-04-17  $2900.45
# 2019-04-18  $2905.03
# 2019-04-22  $2907.97
# 2019-04-23  $2933.68
#
# [1649 rows x 1 columns]

# %%
sp500.Close
# Out:
# Date
# 2012-10-01    $1444.49
# 2012-10-02    $1445.75
# 2012-10-03    $1450.99
# 2012-10-04    $1461.40
# 2012-10-05    $1460.93
#                 ...
# 2019-04-16    $2907.06
# 2019-04-17    $2900.45
# 2019-04-18    $2905.03
# 2019-04-22    $2907.97
# 2019-04-23    $2933.68
# Name: Close, Length: 1649, dtype: object

# %%
# Check Data Types
sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1649 entries, 2012-10-01 to 2019-04-23
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1649 non-null   object
# dtypes: object(1)
# memory usage: 25.8+ KB

# %%
# Fix Data Types (convert "Close" column from object to float)

# Remove "$" sign from values in "Close" column and convert data type from "object" to "float"
sp500["Close"] = sp500["Close"].str.replace("$", "").astype("float")

# Sort index in ascending order
sp500.sort_index(inplace=True)

# Confirm data type conversion
sp500.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1649 entries, 2012-10-01 to 2019-04-23
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1649 non-null   float64
# dtypes: float64(1)
# memory usage: 25.8 KB

# %%
# Calculate Daily Returns
sp500_Returns = sp500.pct_change()
sp500_Returns = sp500_Returns.rename(columns={'Close': 'sp500'})
sp500_Returns.dropna()
# Out:
#                sp500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
Data = pd.concat([whale,algo,sp500_Returns], axis= 'columns', join= 'inner')
Data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     sp500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
Data.plot(figsize=(20,10), title= "Analysis Daily Returns")

# %%
#cumulative_returns = (1 + returns).cumprod() 
# The cumulative return is the total change in the investment price over a set time—an aggregate return, 
# not an annualized one.

# Plot cumulative returns
Cumulative_Data = (1+Data).cumprod()
Cumulative_Data.plot(figsize=(20,10), title="Cumulative Returns")

# %% [markdown]
# From the cumulative returns The S&P 500 has outpreformed most competitors, and of the group was has the least volitility, making this the better investment if you are looking to mitigate your risk.
#
# Berkshire Hathaway outpreforming the S&P stocks in the end. The stock had it's siginficant number of lows compared to the S&P. Overall it made a recovery and beat the S&P, making Bershire Hathaway a more profitable stock with higher associated risk.
#
# Tiger Global's stock is seen as the most volitile of the group.
#
# Algo 1 was the best preforming above all, with the largest returns, and gains in the market.

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
Data.plot(kind='box', figsize = (20,10), title = 'Risk')

# %%
# Standard deviation tells you how spread out the data is. It is a measure of how far each observed value is from the mean. In any distribution, about 95% of values 
# will be within 2 standard deviations of the mean.
# Higher Std. more risk invloved

# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
DF = pd.DataFrame(Data.std()).rename(columns={0:"Returns"})
DF
# Out:
#                               Returns
# SOROS FUND MANAGEMENT LLC    0.007895
# PAULSON & CO.INC.            0.007023
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919
# Algo 1                       0.007620
# Algo 2                       0.008342
# sp500                        0.008554

# %%
# Determine which portfolios are riskier than the S&P 500


# Determine which portfolios are riskier than the S&P 500
High_Risk = DF[DF["Returns"] > DF.loc["sp500", "Returns"]]
High_Risk
# Out:
#                               Returns
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919

# %%
# Calculate the annualized standard deviation (252 trading days)
Annualized_Data = DF * np.sqrt(252)
Annualized_Data
# Out:
#                               Returns
# SOROS FUND MANAGEMENT LLC    0.125335
# PAULSON & CO.INC.            0.111488
# TIGER GLOBAL MANAGEMENT LLC  0.172936
# BERKSHIRE HATHAWAY INC       0.205077
# Algo 1                       0.120967
# Algo 2                       0.132430
# sp500                        0.135786

# %% [markdown]
# Annualized Std over 252 trading days indicates average variance per day. Berkshire Hawthaway, Tiger Global the largest annual avagerage varaince, have the most risk, involved.

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
#
# There is evidence of positive correlation and covariance among the data, the S&P has a large influence on our dataset, as the correlation describes. A positive correlation and covariance is seen as the values of our varaibles are changing at a constant rate toghether. While volatility and risk increases in the S&P 500, this tends to affect and also increase in the other stocks of our portoflio.
#
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# Algo 2 most closely mimics the S&P500
#
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# The Berkshire Hathaway portfolio is sesnsitve to the movements of the S&P500. The S&P is a major driver in our data, influcening each stock in our portfolio.
#
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.
# EWM = Data.ewm(span=21).std()

# %%
#sp500_rolling_std = daily_returns_df.rolling(window=21).std()
#sp500_rolling_std.plot(figsize = (20,10), title="21-Day Rolling Standard Deviations")
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
Rolling_stats = Data.rolling(window=21).std()
Rolling_stats.plot(figsize = (20,10), title= " Rolling Stats 21 Days")

# %%
# Construct a correlation table
Correlation_Table = Data.corr()
Correlation_Table
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# sp500                                         0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
Covariance = Data['BERKSHIRE HATHAWAY INC'].rolling(window=120).cov(Data['sp500'])
Variance = Data['sp500'].rolling(window=120).var()
Beta = Covariance / Variance
Beta.plot(figsize=(10,5), title="Rolling 120 day BSH")
Beta.dropna()
# Out:
# Date
# 2015-08-20    0.820396
# 2015-08-21    0.786685
# 2015-08-24    0.823082
# 2015-08-25    0.772832
# 2015-08-26    0.776498
#                 ...
# 2019-04-16    1.365100
# 2019-04-17    1.365001
# 2019-04-18    1.348693
# 2019-04-22    1.332517
# 2019-04-23    1.341947
# Length: 924, dtype: float64

# %%
Covariance
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000190
# 2019-04-17    0.000189
# 2019-04-18    0.000176
# 2019-04-22    0.000170
# 2019-04-23    0.000168
# Length: 1043, dtype: float64

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
EWM = Data.ewm(span=21,).mean()
(1+EWM).cumprod().plot(figsize = (20,10), title='Exponential Weighted Average 21-day ')

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
# Algo 1 outprefomes the S&P500 and Whale portfolio, given the sharpe rato of 1.3.

# %%
Data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     sp500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %%
# Calculate annualized Sharpe Ratios
# Annualzied Sharpe Ratios
sharpe_ratio = Data.mean()*252/(Data.std()*np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# sp500                          0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
APPL = pd.read_csv('APPL.csv', index_col="Date", parse_dates=True, infer_datetime_format=True)
APPL = APPL.rename(columns={"Close":"APPL"})
#APL.index = pd.DatetimeIndex(APL.index)
APPL.head()
# Out:
#              APPL
# Date
# 2019-01-02  39.48
# 2019-01-03  35.55
# 2019-01-04  37.07
# 2019-01-07  36.98
# 2019-01-08  37.69

# %%
# Read the second stock
INTC = pd.read_csv('INTC.csv', index_col="Date", parse_dates=True, infer_datetime_format=True)
INTC = INTC.rename(columns={"Close":"INTC"})
INTC.head()
# Out:
#              INTC
# Date
# 2019-01-03  44.49
# 2019-01-04  47.22
# 2019-01-07  47.44
# 2019-01-08  47.74
# 2019-01-09  48.01

# %%
# Read the third stock
NVDA = pd.read_csv('NVDA1.csv', index_col="Date", parse_dates=True, infer_datetime_format=True)
NVDA = NVDA.rename(columns={"Close":"NVDA"})
NVDA.head()
# Out:
#               NVDA
# Date
# 2019-01-03  127.99
# 2019-01-04  136.19
# 2019-01-07  143.40
# 2019-01-08  139.83
# 2019-01-09  142.58

# %%
# Concatenate all stocks into a single DataFrame
Custom = pd.concat([APL,INTC,NVDA], axis= 'columns', join= 'inner')

# %%
Custom.head()
# Out:
#              APPL   INTC    NVDA
# Date
# 2019-01-03  35.55  44.49  127.99
# 2019-01-04  37.07  47.22  136.19
# 2019-01-07  36.98  47.44  143.40
# 2019-01-08  37.69  47.74  139.83
# 2019-01-09  38.33  48.01  142.58

# %%
# Reset the index
Custom.index = Custom.index.normalize()
Custom
# Out:
#               APPL   INTC    NVDA
# Date
# 2019-01-03   35.55  44.49  127.99
# 2019-01-04   37.07  47.22  136.19
# 2019-01-07   36.98  47.44  143.40
# 2019-01-08   37.69  47.74  139.83
# 2019-01-09   38.33  48.01  142.58
# ...            ...    ...     ...
# 2020-12-22  131.88  46.17  531.13
# 2020-12-23  130.96  46.57  520.37
# 2020-12-24  131.97  47.07  519.75
# 2020-12-28  136.69  47.07  516.00
# 2020-12-29  134.87  49.39  517.73
#
# [502 rows x 3 columns]

# %%
# Drop Nulls
Custom.isnull().sum()
# Out:
# APPL    0
# INTC    0
# NVDA    0
# dtype: int64

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
Portfolio = Custom.pct_change().dot(weights)
Portfolio.dropna()
# Out:
# Date
# 2019-01-04    0.056062
# 2019-01-07    0.018391
# 2019-01-08    0.000209
# 2019-01-09    0.014101
# 2019-01-10    0.011058
#                 ...
# 2020-12-22    0.006772
# 2020-12-23   -0.006190
# 2020-12-24    0.005752
# 2020-12-28    0.009517
# 2020-12-29    0.013109
# Length: 501, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
All_Returns = pd.concat([Portfolio, Data], axis = 'columns', join='inner')
All_Returns.rename(columns = {0:"APPL/INTC/NVDA"},inplace=True)
All_Returns.head().dropna()
# Out:
#             APPL/INTC/NVDA  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-01-04        0.056062                   0.029881            0.027032
# 2019-01-07        0.018391                   0.009051            0.014475
# 2019-01-08        0.000209                   0.010760            0.008050
# 2019-01-09        0.014101                   0.008630           -0.000800
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-01-04                     0.033560                0.061341  0.017622
# 2019-01-07                     0.014111                0.017185  0.014748
# 2019-01-08                     0.001544                0.005851  0.010825
# 2019-01-09                    -0.000534                0.019788  0.000214
#
#               Algo 2     sp500
# Date
# 2019-01-04  0.030509  0.034336
# 2019-01-07  0.016942  0.007010
# 2019-01-08  0.010479  0.009695
# 2019-01-09  0.009658  0.004098

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
All_Returns.tail()
# Out:
#             APPL/INTC/NVDA  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16        0.008881                   0.002699            0.000388
# 2019-04-17        0.015736                  -0.002897           -0.006467
# 2019-04-18       -0.000913                   0.001448            0.001222
# 2019-04-22        0.006810                  -0.002586           -0.007333
# 2019-04-23        0.008489                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2     sp500
# Date
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
DF = pd.DataFrame(All_Returns.std()).rename(columns={0:"Standard_Deviation"})
DF
# Out:
#                              Standard_Deviation
# APPL/INTC/NVDA                         0.016102
# SOROS FUND MANAGEMENT LLC              0.007471
# PAULSON & CO.INC.                      0.006958
# TIGER GLOBAL MANAGEMENT LLC            0.018262
# BERKSHIRE HATHAWAY INC                 0.012868
# Algo 1                                 0.005730
# Algo 2                                 0.007657
# sp500                                  0.007886

# %%
# Rolling
#Rolling_Data = All_Returns.rolling(window=21).std()
#Rolling_Data.plot(figsize = (20,10), title= " Rolling Stats 21 Days")

Rolling_Final = All_Returns[["APPL/INTC/NVDA"]].rolling(window = 21).std()
ax = Rolling_Final.plot(figsize = (20,10), title = 'Rolling 21-Day Standard Deviation for AAPL/INTC/NVDA')
ax.legend(["rolling 21"]);

# %%
Rolling_Final_std = All_Returns.rolling(window=30).std()
Rolling_Final_std.plot(figsize = (20,10), title="30-Day Rolling Standard Deviations")

# %%
# Calculate the annualized standard deviation (252 trading days)
# Calculate sharpe ratio

# Annualized Sharpe Ratios
Annualized = All_Returns.mean()*252/(All_Returns.std()*np.sqrt(252))
Annualized.sort_values()
# Out:
# TIGER GLOBAL MANAGEMENT LLC   -0.384135
# PAULSON & CO.INC.              2.364248
# Algo 1                         3.488488
# sp500                          4.196678
# BERKSHIRE HATHAWAY INC         4.442098
# APPL/INTC/NVDA                 4.849819
# SOROS FUND MANAGEMENT LLC      4.998934
# Algo 2                         5.051608
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
Annualized.plot(kind = "bar", title = "Annualized Sharpe Ratios")

# %%
# Create a correlation analysis
All_Returns.corr()
# Out:
#                              APPL/INTC/NVDA  SOROS FUND MANAGEMENT LLC  \
# APPL/INTC/NVDA                     1.000000                   0.660855
# SOROS FUND MANAGEMENT LLC          0.660855                   1.000000
# PAULSON & CO.INC.                  0.577619                   0.749951
# TIGER GLOBAL MANAGEMENT LLC        0.139456                   0.356923
# BERKSHIRE HATHAWAY INC             0.726697                   0.741391
# Algo 1                             0.196588                   0.091970
# Algo 2                             0.683144                   0.807262
# sp500                              0.793899                   0.789750
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# APPL/INTC/NVDA                         0.577619                     0.139456
# SOROS FUND MANAGEMENT LLC              0.749951                     0.356923
# PAULSON & CO.INC.                      1.000000                     0.268720
# ...

# %% [markdown]
# The input data for the APPL/INTC/NVDA correlates srtongest with the S&P500, the least correlated stock in contrast is Tiger Global Management.

# %%
# Beta
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
Cov = All_Returns['APPL/INTC/NVDA'].rolling(window=30).cov(Data['sp500'])
Var = All_Returns['APPL/INTC/NVDA'].rolling(window=30).var()
Beta1 = Cov / Var
Beta1.plot(figsize=(10,5), title="Rolling 30 day APPL/INTC/NVDA")
